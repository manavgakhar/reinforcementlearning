# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ## Comes with crtain important methods/attributes
# - action_space
# - observation_space
# - reset()
# - step()
# - render()

# %%
#no. of diff actions
#move left and move right
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.sample()
# Out:
# 0

# %%
#chooses randomly
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space
#box class is n-dimensional tensor in openAI gym
# Out:
# Box(4,)

# %%
#takes game to initial state. It is a state intialiser
#location,velocity,angular velocity etc.
env.reset()
# Out:
# array([-0.01253915,  0.02703236, -0.01415071, -0.03640447])

# %%
env.render() #opens env window
env.close() #closes env window

# %%
for _ in range(1000):
    
    random_action=env.action_space.sample()
    env.step(random_action)
    env.render()
    
env.close()
# Out:
# C:\Users\manavgakhar\anaconda3\lib\site-packages\gym\logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## Playing game with random strategy

# %%
for e in range(20): #Episode
    #play 20 episodes
    observation=env.reset()
    for t in range(50):
        env.render()
        action= env.action_space.sample()
        observation,reward,done,other_info  = env.step(action)
        
        if done:
            #Game Episode is over
            
            print("Game Episode :{}/{} High Score :{}".format(e,20,t))
            break
env.close()
# Out:
# Game Episode :0/20 High Score :17
# Game Episode :1/20 High Score :10
# Game Episode :2/20 High Score :43
# Game Episode :3/20 High Score :42
# Game Episode :4/20 High Score :15
# Game Episode :5/20 High Score :25
# Game Episode :6/20 High Score :29
# Game Episode :7/20 High Score :26
# Game Episode :8/20 High Score :17
# Game Episode :9/20 High Score :11
# Game Episode :10/20 High Score :46
# Game Episode :11/20 High Score :24
# Game Episode :12/20 High Score :12
# Game Episode :13/20 High Score :12
# Game Episode :14/20 High Score :27
# Game Episode :15/20 High Score :16
# Game Episode :16/20 High Score :11
# Game Episode :17/20 High Score :37
# Game Episode :18/20 High Score :23
# Game Episode :19/20 High Score :12

# %% [markdown]
# ## Q Learning

# %%
# Goal is to maximize the total reward

# %%
# Q is a function for the quality of the reward. It's parameters are states and actions

# %%
# We wil penalize future rewards by a discount factor of gamma

# %% [markdown]
# ### Agent Design and Neural Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import random
# Out:
# Using TensorFlow backend.

# %%
# class Agent:
#     def __init__(self,state_size,action_size):
#         self.state_size= state_size
#         self.action_size=action_size
#         self.memory= deque(maxlen=2000) #agent needs memory as we dont have training data.
#                                         # we will store past experiences of agent to play game. #doubly ended queue.
#         self.gamma= 0.95 #Discount factor
#         #Exploration vs Exploitation trade off
#         # Exploration : (random) is good in beginnnig --> helps you to try various random things
#         #Exploitation : Sample Good experience from the past(memory) --> good in the end
        
#         self.epsilon=1.0 # 100% Random exploration in the beginning
#         self.epsilon_decay= 0.995 # as we play more, random exp. decreases and we start truting our knowledge.
#         self.epsilon_min=0.01
#         self.learning_rate= 0.001
#         self.model= self._create_model()
        
#     def _create_model(self):
#         model= Sequential()
#         model.add(Dense(24,input_dim=self.state_size,activation='relu'))
#         model.add(Dense(24,activation='relu'))
#         model.add(Dense(self.action_size,activation='linear'))
#         model.compile(loss='mse',optimizer=Adam(lr=0.001)) #mse as output is linear 
#         return model
    
#     def remember(self,state,action,reward,next_state,done):
#         self.memory.append(state,action,reward,next_state,done)
        
#     def act(self,state):
#         # Sampling according to the Epsilon Greedy Method
#         if np.random.randn()<= self.epsilon():
            
#             return random.randrange(self.action_size)
        
#         # Ask Neural Network to give most suitable
            
#         return np.argmax(model.predict(state)[0])
        
        
#     def train(self,batch_size):
#         # Training using a replay buffer
        
#         minibatch= random.sample(self.memory,batch_size)
        
#         for experience in minibatch:
#             state,action,reward,next_state,done= experience
            
#             # X,Y : state, expected reward
            
#             if not done:
#                 # game is not yet over, bellman eqn to approx. the target value of reward
                
#                 target= reward + self.gamma*np.amax(self.model.predict(next_state)[0])
#             else:
                
#                 target = reward
            
#             target_f = self.model.predict(state)
#             target[0][action]= target
            
#             #X = state, Y= target_f
            
#             self.model.fit(state,target_f,epochs=1,verbose=0)
        
#         if self.epsilon> self.epsilon_min:
#             self.epsilon*= self.epsilon_decay
    
#     def load(self,name):
        
#         self.model.load_weights(name)

#     def save(self,name):
#         self.model.save_weight(name)

# %%
class Agent:
    def __init__(self,state_size,action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95 #Discount Factor
        self.epsilon = 1.0 # Exploration Rate: How much to act randomly, 
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001 
        self.model = self._create_model()
        
    
    def _create_model(self):
        #Neural Network To Approximate Q-Value function
        model = Sequential()
        model.add(Dense(24,input_dim=self.state_size,activation='relu')) #1st Hidden Layer
        model.add(Dense(24,activation='relu')) #2nd Hidden Layer
        model.add(Dense(self.action_size,activation='linear'))
        model.compile(loss='mse',optimizer=Adam(lr=self.learning_rate))
        return model
    
    def remember(self,state,action,reward,next_state,done):
        self.memory.append((state,action,reward,next_state,done)) #remembering previous experiences
        
    def act(self,state):
        # Exploration vs Exploitation
        if np.random.rand()<=self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state) # predict reward value based upon current state
        return np.argmax(act_values[0]) #Left or Right
    
    def train(self,batch_size=32): #method that trains NN with experiences sampled from memory
        minibatch = random.sample(self.memory,batch_size)
        for state,action,reward,next_state,done in minibatch:
            
            if not done: #boolean 
                target = reward + self.gamma*np.amax(self.model.predict(next_state)[0])
            else:
                target = reward
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state,target_f,epochs=1,verbose=0) #single epoch, x =state, y = target_f, loss--> target_f - 
            
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
    
    def load(self,name):
        self.model.load_weights(name)
    def save(self,name):
        self.model.save_weights(name)

# %%
n_episodes= 600
output_dir= "cartpole_model/"

# %%
agent= Agent(state_size=4,action_size=2)
done= False

state_size = 4
action_size =2
batch_size = 32

# %%
for e in range(n_episodes):
    state = env.reset()
    state = np.reshape(state,[1,state_size])
    
    for time in range(5000):
        env.render()
        action = agent.act(state) #action is 0 or 1
        next_state,reward,done,other_info = env.step(action) 
        reward = reward if not done else -10
        next_state = np.reshape(next_state,[1,state_size])
        agent.remember(state,action,reward,next_state,done)
        state = next_state
        
        if done:
            print("Game Episode :{}/{}, High Score:{},Exploration Rate:{:.2}".format(e,n_episodes,time,agent.epsilon))
            break
            
    if len(agent.memory)>batch_size:
        agent.train(batch_size)
    
    if e%50==0:
        agent.save(output_dir+"weights_"+'{:04d}'.format(e)+".hdf5")
        
env.close()
# Out:
# Game Episode :0/600, High Score:29,Exploration Rate:1.0
# Game Episode :1/600, High Score:41,Exploration Rate:1.0
# Game Episode :2/600, High Score:12,Exploration Rate:0.99
# Game Episode :3/600, High Score:11,Exploration Rate:0.99
# Game Episode :4/600, High Score:15,Exploration Rate:0.99
# Game Episode :5/600, High Score:11,Exploration Rate:0.98
# Game Episode :6/600, High Score:14,Exploration Rate:0.98
# Game Episode :7/600, High Score:12,Exploration Rate:0.97
# Game Episode :8/600, High Score:15,Exploration Rate:0.97
# Game Episode :9/600, High Score:23,Exploration Rate:0.96
# Game Episode :10/600, High Score:14,Exploration Rate:0.96
# Game Episode :11/600, High Score:20,Exploration Rate:0.95
# Game Episode :12/600, High Score:23,Exploration Rate:0.95
# Game Episode :13/600, High Score:51,Exploration Rate:0.94
# Game Episode :14/600, High Score:26,Exploration Rate:0.94
# Game Episode :15/600, High Score:11,Exploration Rate:0.93
# Game Episode :16/600, High Score:14,Exploration Rate:0.93
# Game Episode :17/600, High Score:22,Exploration Rate:0.92
# Game Episode :18/600, High Score:12,Exploration Rate:0.92
# Game Episode :19/600, High Score:17,Exploration Rate:0.91
# Game Episode :20/600, High Score:19,Exploration Rate:0.91
# Game Episode :21/600, High Score:23,Exploration Rate:0.9
# Game Episode :22/600, High Score:11,Exploration Rate:0.9
# Game Episode :23/600, High Score:18,Exploration Rate:0.9
# Game Episode :24/600, High Score:14,Exploration Rate:0.89
# Game Episode :25/600, High Score:16,Exploration Rate:0.89
# Game Episode :26/600, High Score:9,Exploration Rate:0.88
# Game Episode :27/600, High Score:21,Exploration Rate:0.88
# Game Episode :28/600, High Score:13,Exploration Rate:0.87
# Game Episode :29/600, High Score:20,Exploration Rate:0.87
# Game Episode :30/600, High Score:13,Exploration Rate:0.86
# Game Episode :31/600, High Score:33,Exploration Rate:0.86
# Game Episode :32/600, High Score:9,Exploration Rate:0.86
# Game Episode :33/600, High Score:13,Exploration Rate:0.85
# Game Episode :34/600, High Score:14,Exploration Rate:0.85
# Game Episode :35/600, High Score:30,Exploration Rate:0.84
# Game Episode :36/600, High Score:15,Exploration Rate:0.84
# Game Episode :37/600, High Score:22,Exploration Rate:0.83
# Game Episode :38/600, High Score:19,Exploration Rate:0.83
# Game Episode :39/600, High Score:13,Exploration Rate:0.83
# Game Episode :40/600, High Score:14,Exploration Rate:0.82
# Game Episode :41/600, High Score:12,Exploration Rate:0.82
# Game Episode :42/600, High Score:12,Exploration Rate:0.81
# Game Episode :43/600, High Score:18,Exploration Rate:0.81
# Game Episode :44/600, High Score:10,Exploration Rate:0.81
# Game Episode :45/600, High Score:13,Exploration Rate:0.8
# Game Episode :46/600, High Score:19,Exploration Rate:0.8
# Game Episode :47/600, High Score:23,Exploration Rate:0.79
# Game Episode :48/600, High Score:59,Exploration Rate:0.79
# Game Episode :49/600, High Score:29,Exploration Rate:0.79
# Game Episode :50/600, High Score:9,Exploration Rate:0.78
# Game Episode :51/600, High Score:51,Exploration Rate:0.78
# Game Episode :52/600, High Score:15,Exploration Rate:0.77
# Game Episode :53/600, High Score:15,Exploration Rate:0.77
# Game Episode :54/600, High Score:25,Exploration Rate:0.77
# Game Episode :55/600, High Score:22,Exploration Rate:0.76
# Game Episode :56/600, High Score:14,Exploration Rate:0.76
# Game Episode :57/600, High Score:21,Exploration Rate:0.76
# Game Episode :58/600, High Score:19,Exploration Rate:0.75
# Game Episode :59/600, High Score:19,Exploration Rate:0.75
# Game Episode :60/600, High Score:24,Exploration Rate:0.74
# Game Episode :61/600, High Score:49,Exploration Rate:0.74
# Game Episode :62/600, High Score:32,Exploration Rate:0.74
# Game Episode :63/600, High Score:21,Exploration Rate:0.73
# Game Episode :64/600, High Score:36,Exploration Rate:0.73
# Game Episode :65/600, High Score:28,Exploration Rate:0.73
# Game Episode :66/600, High Score:30,Exploration Rate:0.72
# Game Episode :67/600, High Score:40,Exploration Rate:0.72
# Game Episode :68/600, High Score:19,Exploration Rate:0.71
# Game Episode :69/600, High Score:14,Exploration Rate:0.71
# Game Episode :70/600, High Score:57,Exploration Rate:0.71
# Game Episode :71/600, High Score:28,Exploration Rate:0.7
# Game Episode :72/600, High Score:48,Exploration Rate:0.7
# Game Episode :73/600, High Score:21,Exploration Rate:0.7
# Game Episode :74/600, High Score:22,Exploration Rate:0.69
# Game Episode :75/600, High Score:33,Exploration Rate:0.69
# Game Episode :76/600, High Score:15,Exploration Rate:0.69
# Game Episode :77/600, High Score:21,Exploration Rate:0.68
# Game Episode :78/600, High Score:33,Exploration Rate:0.68
# Game Episode :79/600, High Score:20,Exploration Rate:0.68
# Game Episode :80/600, High Score:19,Exploration Rate:0.67
# Game Episode :81/600, High Score:21,Exploration Rate:0.67
# Game Episode :82/600, High Score:23,Exploration Rate:0.67
# Game Episode :83/600, High Score:19,Exploration Rate:0.66
# Game Episode :84/600, High Score:15,Exploration Rate:0.66
# Game Episode :85/600, High Score:46,Exploration Rate:0.66
# Game Episode :86/600, High Score:26,Exploration Rate:0.65
# Game Episode :87/600, High Score:38,Exploration Rate:0.65
# Game Episode :88/600, High Score:17,Exploration Rate:0.65
# Game Episode :89/600, High Score:15,Exploration Rate:0.64
# Game Episode :90/600, High Score:14,Exploration Rate:0.64
# Game Episode :91/600, High Score:15,Exploration Rate:0.64
# Game Episode :92/600, High Score:11,Exploration Rate:0.63
# Game Episode :93/600, High Score:17,Exploration Rate:0.63
# Game Episode :94/600, High Score:24,Exploration Rate:0.63
# Game Episode :95/600, High Score:25,Exploration Rate:0.62
# Game Episode :96/600, High Score:37,Exploration Rate:0.62
# Game Episode :97/600, High Score:19,Exploration Rate:0.62
# Game Episode :98/600, High Score:60,Exploration Rate:0.61
# Game Episode :99/600, High Score:30,Exploration Rate:0.61
# Game Episode :100/600, High Score:11,Exploration Rate:0.61
# Game Episode :101/600, High Score:45,Exploration Rate:0.61
# Game Episode :102/600, High Score:32,Exploration Rate:0.6
# Game Episode :103/600, High Score:19,Exploration Rate:0.6
# Game Episode :104/600, High Score:45,Exploration Rate:0.6
# Game Episode :105/600, High Score:51,Exploration Rate:0.59
# Game Episode :106/600, High Score:19,Exploration Rate:0.59
# Game Episode :107/600, High Score:28,Exploration Rate:0.59
# Game Episode :108/600, High Score:28,Exploration Rate:0.58
# Game Episode :109/600, High Score:22,Exploration Rate:0.58
# Game Episode :110/600, High Score:40,Exploration Rate:0.58
# Game Episode :111/600, High Score:55,Exploration Rate:0.58
# Game Episode :112/600, High Score:140,Exploration Rate:0.57
# Game Episode :113/600, High Score:59,Exploration Rate:0.57
# Game Episode :114/600, High Score:119,Exploration Rate:0.57
# Game Episode :115/600, High Score:90,Exploration Rate:0.56
# Game Episode :116/600, High Score:63,Exploration Rate:0.56
# Game Episode :117/600, High Score:53,Exploration Rate:0.56
# Game Episode :118/600, High Score:19,Exploration Rate:0.56
# Game Episode :119/600, High Score:19,Exploration Rate:0.55
# Game Episode :120/600, High Score:15,Exploration Rate:0.55
# Game Episode :121/600, High Score:20,Exploration Rate:0.55
# Game Episode :122/600, High Score:78,Exploration Rate:0.55
# Game Episode :123/600, High Score:21,Exploration Rate:0.54
# Game Episode :124/600, High Score:28,Exploration Rate:0.54
# Game Episode :125/600, High Score:121,Exploration Rate:0.54
# Game Episode :126/600, High Score:98,Exploration Rate:0.53
# Game Episode :127/600, High Score:16,Exploration Rate:0.53
# Game Episode :128/600, High Score:20,Exploration Rate:0.53
# Game Episode :129/600, High Score:41,Exploration Rate:0.53
# Game Episode :130/600, High Score:14,Exploration Rate:0.52
# Game Episode :131/600, High Score:16,Exploration Rate:0.52
# Game Episode :132/600, High Score:11,Exploration Rate:0.52
# Game Episode :133/600, High Score:13,Exploration Rate:0.52
# Game Episode :134/600, High Score:12,Exploration Rate:0.51
# Game Episode :135/600, High Score:17,Exploration Rate:0.51
# Game Episode :136/600, High Score:14,Exploration Rate:0.51
# Game Episode :137/600, High Score:9,Exploration Rate:0.51
# Game Episode :138/600, High Score:8,Exploration Rate:0.5
# Game Episode :139/600, High Score:11,Exploration Rate:0.5
# Game Episode :140/600, High Score:9,Exploration Rate:0.5
# Game Episode :141/600, High Score:9,Exploration Rate:0.5
# Game Episode :142/600, High Score:10,Exploration Rate:0.49
# Game Episode :143/600, High Score:13,Exploration Rate:0.49
# Game Episode :144/600, High Score:8,Exploration Rate:0.49
# Game Episode :145/600, High Score:14,Exploration Rate:0.49
# Game Episode :146/600, High Score:24,Exploration Rate:0.48
# Game Episode :147/600, High Score:79,Exploration Rate:0.48
# Game Episode :148/600, High Score:20,Exploration Rate:0.48
# Game Episode :149/600, High Score:23,Exploration Rate:0.48
# Game Episode :150/600, High Score:111,Exploration Rate:0.47
# Game Episode :151/600, High Score:44,Exploration Rate:0.47
# Game Episode :152/600, High Score:49,Exploration Rate:0.47
# Game Episode :153/600, High Score:70,Exploration Rate:0.47
# Game Episode :154/600, High Score:47,Exploration Rate:0.46
# Game Episode :155/600, High Score:44,Exploration Rate:0.46
# Game Episode :156/600, High Score:101,Exploration Rate:0.46
# Game Episode :157/600, High Score:25,Exploration Rate:0.46
# Game Episode :158/600, High Score:102,Exploration Rate:0.46
# Game Episode :159/600, High Score:111,Exploration Rate:0.45
# Game Episode :160/600, High Score:128,Exploration Rate:0.45
# Game Episode :161/600, High Score:12,Exploration Rate:0.45
# Game Episode :162/600, High Score:18,Exploration Rate:0.45
# Game Episode :163/600, High Score:23,Exploration Rate:0.44
# Game Episode :164/600, High Score:24,Exploration Rate:0.44
# Game Episode :165/600, High Score:35,Exploration Rate:0.44
# Game Episode :166/600, High Score:17,Exploration Rate:0.44
# Game Episode :167/600, High Score:16,Exploration Rate:0.44
# Game Episode :168/600, High Score:18,Exploration Rate:0.43
# Game Episode :169/600, High Score:38,Exploration Rate:0.43
# Game Episode :170/600, High Score:134,Exploration Rate:0.43
# Game Episode :171/600, High Score:52,Exploration Rate:0.43
# Game Episode :172/600, High Score:15,Exploration Rate:0.42
# Game Episode :173/600, High Score:199,Exploration Rate:0.42
# Game Episode :174/600, High Score:25,Exploration Rate:0.42
# Game Episode :175/600, High Score:35,Exploration Rate:0.42
# Game Episode :176/600, High Score:123,Exploration Rate:0.42
# Game Episode :177/600, High Score:122,Exploration Rate:0.41
# Game Episode :178/600, High Score:29,Exploration Rate:0.41
# Game Episode :179/600, High Score:14,Exploration Rate:0.41
# Game Episode :180/600, High Score:199,Exploration Rate:0.41
# Game Episode :181/600, High Score:158,Exploration Rate:0.41
# Game Episode :182/600, High Score:116,Exploration Rate:0.4
# Game Episode :183/600, High Score:171,Exploration Rate:0.4
# Game Episode :184/600, High Score:34,Exploration Rate:0.4
# Game Episode :185/600, High Score:64,Exploration Rate:0.4
# Game Episode :186/600, High Score:124,Exploration Rate:0.4
# Game Episode :187/600, High Score:62,Exploration Rate:0.39
# Game Episode :188/600, High Score:13,Exploration Rate:0.39
# Game Episode :189/600, High Score:18,Exploration Rate:0.39
# Game Episode :190/600, High Score:16,Exploration Rate:0.39
# Game Episode :191/600, High Score:26,Exploration Rate:0.39
# Game Episode :192/600, High Score:23,Exploration Rate:0.38
# Game Episode :193/600, High Score:118,Exploration Rate:0.38
# Game Episode :194/600, High Score:13,Exploration Rate:0.38
# Game Episode :195/600, High Score:17,Exploration Rate:0.38
# Game Episode :196/600, High Score:10,Exploration Rate:0.38
# Game Episode :197/600, High Score:11,Exploration Rate:0.37
# Game Episode :198/600, High Score:21,Exploration Rate:0.37
# Game Episode :199/600, High Score:13,Exploration Rate:0.37
# Game Episode :200/600, High Score:10,Exploration Rate:0.37
# Game Episode :201/600, High Score:22,Exploration Rate:0.37
# Game Episode :202/600, High Score:15,Exploration Rate:0.37
# Game Episode :203/600, High Score:9,Exploration Rate:0.36
# Game Episode :204/600, High Score:19,Exploration Rate:0.36
# Game Episode :205/600, High Score:13,Exploration Rate:0.36
# Game Episode :206/600, High Score:13,Exploration Rate:0.36
# Game Episode :207/600, High Score:13,Exploration Rate:0.36
# Game Episode :208/600, High Score:13,Exploration Rate:0.35
# Game Episode :209/600, High Score:18,Exploration Rate:0.35
# Game Episode :210/600, High Score:12,Exploration Rate:0.35
# Game Episode :211/600, High Score:14,Exploration Rate:0.35
# Game Episode :212/600, High Score:13,Exploration Rate:0.35
# Game Episode :213/600, High Score:19,Exploration Rate:0.35
# Game Episode :214/600, High Score:19,Exploration Rate:0.34
# Game Episode :215/600, High Score:32,Exploration Rate:0.34
# Game Episode :216/600, High Score:98,Exploration Rate:0.34
# Game Episode :217/600, High Score:36,Exploration Rate:0.34
# Game Episode :218/600, High Score:115,Exploration Rate:0.34
# Game Episode :219/600, High Score:199,Exploration Rate:0.34
# Game Episode :220/600, High Score:169,Exploration Rate:0.33
# Game Episode :221/600, High Score:199,Exploration Rate:0.33
# Game Episode :222/600, High Score:101,Exploration Rate:0.33
# Game Episode :223/600, High Score:105,Exploration Rate:0.33
# Game Episode :224/600, High Score:71,Exploration Rate:0.33
# Game Episode :225/600, High Score:128,Exploration Rate:0.33
# Game Episode :226/600, High Score:94,Exploration Rate:0.32
# Game Episode :227/600, High Score:106,Exploration Rate:0.32
# Game Episode :228/600, High Score:113,Exploration Rate:0.32
# Game Episode :229/600, High Score:79,Exploration Rate:0.32
# Game Episode :230/600, High Score:34,Exploration Rate:0.32
# Game Episode :231/600, High Score:108,Exploration Rate:0.32
# Game Episode :232/600, High Score:18,Exploration Rate:0.31
# Game Episode :233/600, High Score:16,Exploration Rate:0.31
# Game Episode :234/600, High Score:39,Exploration Rate:0.31
# Game Episode :235/600, High Score:24,Exploration Rate:0.31
# Game Episode :236/600, High Score:69,Exploration Rate:0.31
# Game Episode :237/600, High Score:23,Exploration Rate:0.31
# Game Episode :238/600, High Score:71,Exploration Rate:0.3
# Game Episode :239/600, High Score:109,Exploration Rate:0.3
# Game Episode :240/600, High Score:42,Exploration Rate:0.3
# Game Episode :241/600, High Score:104,Exploration Rate:0.3
# Game Episode :242/600, High Score:40,Exploration Rate:0.3
# Game Episode :243/600, High Score:88,Exploration Rate:0.3
# Game Episode :244/600, High Score:19,Exploration Rate:0.3
# Game Episode :245/600, High Score:13,Exploration Rate:0.29
# Game Episode :246/600, High Score:199,Exploration Rate:0.29
# Game Episode :247/600, High Score:199,Exploration Rate:0.29
# Game Episode :248/600, High Score:199,Exploration Rate:0.29
# Game Episode :249/600, High Score:199,Exploration Rate:0.29
# Game Episode :250/600, High Score:199,Exploration Rate:0.29
# Game Episode :251/600, High Score:199,Exploration Rate:0.29
# Game Episode :252/600, High Score:19,Exploration Rate:0.28
# Game Episode :253/600, High Score:39,Exploration Rate:0.28
# Game Episode :254/600, High Score:40,Exploration Rate:0.28
# Game Episode :255/600, High Score:165,Exploration Rate:0.28
# Game Episode :256/600, High Score:149,Exploration Rate:0.28
# Game Episode :257/600, High Score:36,Exploration Rate:0.28
# Game Episode :258/600, High Score:199,Exploration Rate:0.28
# Game Episode :259/600, High Score:199,Exploration Rate:0.27
# Game Episode :260/600, High Score:163,Exploration Rate:0.27
# Game Episode :261/600, High Score:177,Exploration Rate:0.27
# Game Episode :262/600, High Score:163,Exploration Rate:0.27
# Game Episode :263/600, High Score:199,Exploration Rate:0.27
# Game Episode :264/600, High Score:199,Exploration Rate:0.27
# Game Episode :265/600, High Score:199,Exploration Rate:0.27
# Game Episode :266/600, High Score:130,Exploration Rate:0.26
# Game Episode :267/600, High Score:43,Exploration Rate:0.26
# Game Episode :268/600, High Score:118,Exploration Rate:0.26
# Game Episode :269/600, High Score:87,Exploration Rate:0.26
# Game Episode :270/600, High Score:118,Exploration Rate:0.26
# Game Episode :271/600, High Score:82,Exploration Rate:0.26
# Game Episode :272/600, High Score:90,Exploration Rate:0.26
# Game Episode :273/600, High Score:106,Exploration Rate:0.26
# Game Episode :274/600, High Score:68,Exploration Rate:0.25
# Game Episode :275/600, High Score:23,Exploration Rate:0.25
# Game Episode :276/600, High Score:16,Exploration Rate:0.25
# Game Episode :277/600, High Score:28,Exploration Rate:0.25
# Game Episode :278/600, High Score:16,Exploration Rate:0.25
# Game Episode :279/600, High Score:153,Exploration Rate:0.25
# Game Episode :280/600, High Score:148,Exploration Rate:0.25
# Game Episode :281/600, High Score:115,Exploration Rate:0.25
# Game Episode :282/600, High Score:94,Exploration Rate:0.24
# Game Episode :283/600, High Score:95,Exploration Rate:0.24
# Game Episode :284/600, High Score:185,Exploration Rate:0.24
# Game Episode :285/600, High Score:44,Exploration Rate:0.24
# Game Episode :286/600, High Score:94,Exploration Rate:0.24
# Game Episode :287/600, High Score:28,Exploration Rate:0.24
# Game Episode :288/600, High Score:199,Exploration Rate:0.24
# Game Episode :289/600, High Score:199,Exploration Rate:0.24
# Game Episode :290/600, High Score:199,Exploration Rate:0.23
# Game Episode :291/600, High Score:177,Exploration Rate:0.23
# Game Episode :292/600, High Score:107,Exploration Rate:0.23
# Game Episode :293/600, High Score:125,Exploration Rate:0.23
# Game Episode :294/600, High Score:199,Exploration Rate:0.23
# Game Episode :295/600, High Score:177,Exploration Rate:0.23
# Game Episode :296/600, High Score:199,Exploration Rate:0.23
# Game Episode :297/600, High Score:120,Exploration Rate:0.23
# Game Episode :298/600, High Score:152,Exploration Rate:0.23
# Game Episode :299/600, High Score:126,Exploration Rate:0.22
# Game Episode :300/600, High Score:199,Exploration Rate:0.22
# Game Episode :301/600, High Score:187,Exploration Rate:0.22
# Game Episode :302/600, High Score:199,Exploration Rate:0.22
# Game Episode :303/600, High Score:106,Exploration Rate:0.22
# Game Episode :304/600, High Score:156,Exploration Rate:0.22
# Game Episode :305/600, High Score:109,Exploration Rate:0.22
# Game Episode :306/600, High Score:122,Exploration Rate:0.22
# Game Episode :307/600, High Score:171,Exploration Rate:0.22
# Game Episode :308/600, High Score:20,Exploration Rate:0.21
# Game Episode :309/600, High Score:67,Exploration Rate:0.21
# Game Episode :310/600, High Score:121,Exploration Rate:0.21
# Game Episode :311/600, High Score:90,Exploration Rate:0.21
# Game Episode :312/600, High Score:99,Exploration Rate:0.21
# Game Episode :313/600, High Score:133,Exploration Rate:0.21
# Game Episode :314/600, High Score:93,Exploration Rate:0.21
# Game Episode :315/600, High Score:29,Exploration Rate:0.21
# Game Episode :316/600, High Score:17,Exploration Rate:0.21
# Game Episode :317/600, High Score:73,Exploration Rate:0.21
# Game Episode :318/600, High Score:100,Exploration Rate:0.2
# Game Episode :319/600, High Score:133,Exploration Rate:0.2
# Game Episode :320/600, High Score:58,Exploration Rate:0.2
# Game Episode :321/600, High Score:140,Exploration Rate:0.2
# Game Episode :322/600, High Score:88,Exploration Rate:0.2
# Game Episode :323/600, High Score:88,Exploration Rate:0.2
# Game Episode :324/600, High Score:199,Exploration Rate:0.2
# Game Episode :325/600, High Score:199,Exploration Rate:0.2
# Game Episode :326/600, High Score:189,Exploration Rate:0.2
# Game Episode :327/600, High Score:44,Exploration Rate:0.2
# Game Episode :328/600, High Score:17,Exploration Rate:0.19
# Game Episode :329/600, High Score:51,Exploration Rate:0.19
# Game Episode :330/600, High Score:199,Exploration Rate:0.19
# Game Episode :331/600, High Score:199,Exploration Rate:0.19
# Game Episode :332/600, High Score:199,Exploration Rate:0.19
# Game Episode :333/600, High Score:199,Exploration Rate:0.19
# Game Episode :334/600, High Score:199,Exploration Rate:0.19
# Game Episode :335/600, High Score:199,Exploration Rate:0.19
# Game Episode :336/600, High Score:199,Exploration Rate:0.19
# Game Episode :337/600, High Score:199,Exploration Rate:0.19
# Game Episode :338/600, High Score:31,Exploration Rate:0.18
# Game Episode :339/600, High Score:106,Exploration Rate:0.18
# Game Episode :340/600, High Score:199,Exploration Rate:0.18
# Game Episode :341/600, High Score:199,Exploration Rate:0.18
# Game Episode :342/600, High Score:78,Exploration Rate:0.18
# Game Episode :343/600, High Score:199,Exploration Rate:0.18
# Game Episode :344/600, High Score:40,Exploration Rate:0.18
# Game Episode :345/600, High Score:163,Exploration Rate:0.18
# Game Episode :346/600, High Score:199,Exploration Rate:0.18
# Game Episode :347/600, High Score:199,Exploration Rate:0.18
# Game Episode :348/600, High Score:199,Exploration Rate:0.18
# Game Episode :349/600, High Score:199,Exploration Rate:0.17
# Game Episode :350/600, High Score:199,Exploration Rate:0.17
# Game Episode :351/600, High Score:199,Exploration Rate:0.17
# Game Episode :352/600, High Score:199,Exploration Rate:0.17
# Game Episode :353/600, High Score:199,Exploration Rate:0.17
# Game Episode :354/600, High Score:199,Exploration Rate:0.17
# Game Episode :355/600, High Score:183,Exploration Rate:0.17
# Game Episode :356/600, High Score:199,Exploration Rate:0.17
# Game Episode :357/600, High Score:199,Exploration Rate:0.17
# Game Episode :358/600, High Score:25,Exploration Rate:0.17
# Game Episode :359/600, High Score:199,Exploration Rate:0.17
# Game Episode :360/600, High Score:199,Exploration Rate:0.17
# Game Episode :361/600, High Score:199,Exploration Rate:0.16
# Game Episode :362/600, High Score:199,Exploration Rate:0.16
# Game Episode :363/600, High Score:199,Exploration Rate:0.16
# Game Episode :364/600, High Score:199,Exploration Rate:0.16
# Game Episode :365/600, High Score:199,Exploration Rate:0.16
# Game Episode :366/600, High Score:199,Exploration Rate:0.16
# Game Episode :367/600, High Score:187,Exploration Rate:0.16
# Game Episode :368/600, High Score:57,Exploration Rate:0.16
# Game Episode :369/600, High Score:105,Exploration Rate:0.16
# Game Episode :370/600, High Score:26,Exploration Rate:0.16
# Game Episode :371/600, High Score:82,Exploration Rate:0.16
# Game Episode :372/600, High Score:108,Exploration Rate:0.16
# Game Episode :373/600, High Score:199,Exploration Rate:0.15
# Game Episode :374/600, High Score:199,Exploration Rate:0.15
# Game Episode :375/600, High Score:199,Exploration Rate:0.15
# Game Episode :376/600, High Score:199,Exploration Rate:0.15
# Game Episode :377/600, High Score:199,Exploration Rate:0.15
# Game Episode :378/600, High Score:67,Exploration Rate:0.15
# Game Episode :379/600, High Score:100,Exploration Rate:0.15
# Game Episode :380/600, High Score:194,Exploration Rate:0.15
# Game Episode :381/600, High Score:199,Exploration Rate:0.15
# Game Episode :382/600, High Score:199,Exploration Rate:0.15
# Game Episode :383/600, High Score:199,Exploration Rate:0.15
# Game Episode :384/600, High Score:199,Exploration Rate:0.15
# Game Episode :385/600, High Score:199,Exploration Rate:0.15
# Game Episode :386/600, High Score:199,Exploration Rate:0.15
# Game Episode :387/600, High Score:199,Exploration Rate:0.14
# Game Episode :388/600, High Score:199,Exploration Rate:0.14
# Game Episode :389/600, High Score:104,Exploration Rate:0.14
# Game Episode :390/600, High Score:72,Exploration Rate:0.14
# Game Episode :391/600, High Score:108,Exploration Rate:0.14
# Game Episode :392/600, High Score:113,Exploration Rate:0.14
# Game Episode :393/600, High Score:85,Exploration Rate:0.14
# Game Episode :394/600, High Score:127,Exploration Rate:0.14
# Game Episode :395/600, High Score:23,Exploration Rate:0.14
# Game Episode :396/600, High Score:199,Exploration Rate:0.14
# Game Episode :397/600, High Score:199,Exploration Rate:0.14
# Game Episode :398/600, High Score:199,Exploration Rate:0.14
# Game Episode :399/600, High Score:96,Exploration Rate:0.14
# Game Episode :400/600, High Score:22,Exploration Rate:0.14
# Game Episode :401/600, High Score:65,Exploration Rate:0.13
# Game Episode :402/600, High Score:89,Exploration Rate:0.13
# Game Episode :403/600, High Score:80,Exploration Rate:0.13
# Game Episode :404/600, High Score:118,Exploration Rate:0.13
# Game Episode :405/600, High Score:103,Exploration Rate:0.13
# Game Episode :406/600, High Score:126,Exploration Rate:0.13
# Game Episode :407/600, High Score:137,Exploration Rate:0.13
# Game Episode :408/600, High Score:173,Exploration Rate:0.13
# Game Episode :409/600, High Score:25,Exploration Rate:0.13
# Game Episode :410/600, High Score:67,Exploration Rate:0.13
# Game Episode :411/600, High Score:122,Exploration Rate:0.13
# Game Episode :412/600, High Score:189,Exploration Rate:0.13
# Game Episode :413/600, High Score:199,Exploration Rate:0.13
# Game Episode :414/600, High Score:18,Exploration Rate:0.13
# Game Episode :415/600, High Score:15,Exploration Rate:0.13
# Game Episode :416/600, High Score:20,Exploration Rate:0.12
# Game Episode :417/600, High Score:75,Exploration Rate:0.12
# Game Episode :418/600, High Score:47,Exploration Rate:0.12
# Game Episode :419/600, High Score:199,Exploration Rate:0.12
# Game Episode :420/600, High Score:199,Exploration Rate:0.12
# Game Episode :421/600, High Score:136,Exploration Rate:0.12
# Game Episode :422/600, High Score:116,Exploration Rate:0.12
# Game Episode :423/600, High Score:199,Exploration Rate:0.12
# Game Episode :424/600, High Score:199,Exploration Rate:0.12
# Game Episode :425/600, High Score:190,Exploration Rate:0.12
# Game Episode :426/600, High Score:199,Exploration Rate:0.12
# Game Episode :427/600, High Score:40,Exploration Rate:0.12
# Game Episode :428/600, High Score:199,Exploration Rate:0.12
# Game Episode :429/600, High Score:199,Exploration Rate:0.12
# Game Episode :430/600, High Score:199,Exploration Rate:0.12
# Game Episode :431/600, High Score:199,Exploration Rate:0.12
# Game Episode :432/600, High Score:199,Exploration Rate:0.12
# Game Episode :433/600, High Score:199,Exploration Rate:0.11
# Game Episode :434/600, High Score:124,Exploration Rate:0.11
# Game Episode :435/600, High Score:83,Exploration Rate:0.11
# Game Episode :436/600, High Score:199,Exploration Rate:0.11
# Game Episode :437/600, High Score:166,Exploration Rate:0.11
# Game Episode :438/600, High Score:199,Exploration Rate:0.11
# Game Episode :439/600, High Score:199,Exploration Rate:0.11
# Game Episode :440/600, High Score:93,Exploration Rate:0.11
# Game Episode :441/600, High Score:199,Exploration Rate:0.11
# Game Episode :442/600, High Score:199,Exploration Rate:0.11
# Game Episode :443/600, High Score:188,Exploration Rate:0.11
# Game Episode :444/600, High Score:197,Exploration Rate:0.11
# Game Episode :445/600, High Score:194,Exploration Rate:0.11
# Game Episode :446/600, High Score:199,Exploration Rate:0.11
# Game Episode :447/600, High Score:199,Exploration Rate:0.11
# Game Episode :448/600, High Score:19,Exploration Rate:0.11
# Game Episode :449/600, High Score:19,Exploration Rate:0.11
# Game Episode :450/600, High Score:135,Exploration Rate:0.11
# Game Episode :451/600, High Score:199,Exploration Rate:0.1
# Game Episode :452/600, High Score:89,Exploration Rate:0.1
# Game Episode :453/600, High Score:199,Exploration Rate:0.1
# Game Episode :454/600, High Score:187,Exploration Rate:0.1
# Game Episode :455/600, High Score:137,Exploration Rate:0.1
# Game Episode :456/600, High Score:112,Exploration Rate:0.1
# Game Episode :457/600, High Score:103,Exploration Rate:0.1
# Game Episode :458/600, High Score:28,Exploration Rate:0.1
# Game Episode :459/600, High Score:109,Exploration Rate:0.1
# Game Episode :460/600, High Score:160,Exploration Rate:0.1
# Game Episode :461/600, High Score:199,Exploration Rate:0.1
# Game Episode :462/600, High Score:107,Exploration Rate:0.099
# Game Episode :463/600, High Score:199,Exploration Rate:0.099
# Game Episode :464/600, High Score:199,Exploration Rate:0.098
# Game Episode :465/600, High Score:38,Exploration Rate:0.098
# Game Episode :466/600, High Score:183,Exploration Rate:0.097
# Game Episode :467/600, High Score:43,Exploration Rate:0.097
# Game Episode :468/600, High Score:141,Exploration Rate:0.096
# Game Episode :469/600, High Score:107,Exploration Rate:0.096
# Game Episode :470/600, High Score:136,Exploration Rate:0.095
# Game Episode :471/600, High Score:192,Exploration Rate:0.095
# Game Episode :472/600, High Score:199,Exploration Rate:0.094
# Game Episode :473/600, High Score:107,Exploration Rate:0.094
# Game Episode :474/600, High Score:111,Exploration Rate:0.093
# Game Episode :475/600, High Score:15,Exploration Rate:0.093
# Game Episode :476/600, High Score:13,Exploration Rate:0.092
# Game Episode :477/600, High Score:20,Exploration Rate:0.092
# Game Episode :478/600, High Score:24,Exploration Rate:0.092
# Game Episode :479/600, High Score:23,Exploration Rate:0.091
# Game Episode :480/600, High Score:23,Exploration Rate:0.091
# Game Episode :481/600, High Score:21,Exploration Rate:0.09
# Game Episode :482/600, High Score:19,Exploration Rate:0.09
# Game Episode :483/600, High Score:25,Exploration Rate:0.089
# Game Episode :484/600, High Score:24,Exploration Rate:0.089
# Game Episode :485/600, High Score:12,Exploration Rate:0.088
# Game Episode :486/600, High Score:12,Exploration Rate:0.088
# Game Episode :487/600, High Score:95,Exploration Rate:0.088
# Game Episode :488/600, High Score:171,Exploration Rate:0.087
# Game Episode :489/600, High Score:194,Exploration Rate:0.087
# Game Episode :490/600, High Score:199,Exploration Rate:0.086
# Game Episode :491/600, High Score:185,Exploration Rate:0.086
# Game Episode :492/600, High Score:159,Exploration Rate:0.085
# Game Episode :493/600, High Score:41,Exploration Rate:0.085
# Game Episode :494/600, High Score:20,Exploration Rate:0.084
# Game Episode :495/600, High Score:20,Exploration Rate:0.084
# Game Episode :496/600, High Score:35,Exploration Rate:0.084
# Game Episode :497/600, High Score:109,Exploration Rate:0.083
# Game Episode :498/600, High Score:38,Exploration Rate:0.083
# Game Episode :499/600, High Score:199,Exploration Rate:0.082
# Game Episode :500/600, High Score:162,Exploration Rate:0.082
# Game Episode :501/600, High Score:27,Exploration Rate:0.082
# Game Episode :502/600, High Score:26,Exploration Rate:0.081
# Game Episode :503/600, High Score:19,Exploration Rate:0.081
# Game Episode :504/600, High Score:14,Exploration Rate:0.08
# Game Episode :505/600, High Score:16,Exploration Rate:0.08
# Game Episode :506/600, High Score:13,Exploration Rate:0.08
# Game Episode :507/600, High Score:18,Exploration Rate:0.079
# Game Episode :508/600, High Score:9,Exploration Rate:0.079
# Game Episode :509/600, High Score:11,Exploration Rate:0.078
# Game Episode :510/600, High Score:16,Exploration Rate:0.078
# Game Episode :511/600, High Score:17,Exploration Rate:0.078
# Game Episode :512/600, High Score:52,Exploration Rate:0.077
# Game Episode :513/600, High Score:81,Exploration Rate:0.077
# Game Episode :514/600, High Score:199,Exploration Rate:0.076
# Game Episode :515/600, High Score:114,Exploration Rate:0.076
# Game Episode :516/600, High Score:103,Exploration Rate:0.076
# Game Episode :517/600, High Score:105,Exploration Rate:0.075
# Game Episode :518/600, High Score:27,Exploration Rate:0.075
# Game Episode :519/600, High Score:103,Exploration Rate:0.075
# Game Episode :520/600, High Score:169,Exploration Rate:0.074
# Game Episode :521/600, High Score:199,Exploration Rate:0.074
# Game Episode :522/600, High Score:151,Exploration Rate:0.073
# Game Episode :523/600, High Score:140,Exploration Rate:0.073
# Game Episode :524/600, High Score:82,Exploration Rate:0.073
# Game Episode :525/600, High Score:159,Exploration Rate:0.072
# Game Episode :526/600, High Score:127,Exploration Rate:0.072
# Game Episode :527/600, High Score:152,Exploration Rate:0.072
# Game Episode :528/600, High Score:161,Exploration Rate:0.071
# Game Episode :529/600, High Score:185,Exploration Rate:0.071
# Game Episode :530/600, High Score:81,Exploration Rate:0.071
# Game Episode :531/600, High Score:78,Exploration Rate:0.07
# Game Episode :532/600, High Score:138,Exploration Rate:0.07
# Game Episode :533/600, High Score:133,Exploration Rate:0.069
# Game Episode :534/600, High Score:199,Exploration Rate:0.069
# Game Episode :535/600, High Score:199,Exploration Rate:0.069
# Game Episode :536/600, High Score:199,Exploration Rate:0.068
# Game Episode :537/600, High Score:199,Exploration Rate:0.068
# Game Episode :538/600, High Score:199,Exploration Rate:0.068
# Game Episode :539/600, High Score:199,Exploration Rate:0.067
# Game Episode :540/600, High Score:72,Exploration Rate:0.067
# Game Episode :541/600, High Score:144,Exploration Rate:0.067
# Game Episode :542/600, High Score:199,Exploration Rate:0.066
# Game Episode :543/600, High Score:199,Exploration Rate:0.066
# Game Episode :544/600, High Score:199,Exploration Rate:0.066
# Game Episode :545/600, High Score:199,Exploration Rate:0.065
# Game Episode :546/600, High Score:199,Exploration Rate:0.065
# Game Episode :547/600, High Score:105,Exploration Rate:0.065
# Game Episode :548/600, High Score:153,Exploration Rate:0.064
# Game Episode :549/600, High Score:197,Exploration Rate:0.064
# Game Episode :550/600, High Score:199,Exploration Rate:0.064
# Game Episode :551/600, High Score:199,Exploration Rate:0.063
# Game Episode :552/600, High Score:199,Exploration Rate:0.063
# Game Episode :553/600, High Score:199,Exploration Rate:0.063
# Game Episode :554/600, High Score:199,Exploration Rate:0.063
# Game Episode :555/600, High Score:199,Exploration Rate:0.062
# Game Episode :556/600, High Score:199,Exploration Rate:0.062
# Game Episode :557/600, High Score:112,Exploration Rate:0.062
# Game Episode :558/600, High Score:187,Exploration Rate:0.061
# Game Episode :559/600, High Score:145,Exploration Rate:0.061
# Game Episode :560/600, High Score:199,Exploration Rate:0.061
# Game Episode :561/600, High Score:199,Exploration Rate:0.06
# Game Episode :562/600, High Score:199,Exploration Rate:0.06
# Game Episode :563/600, High Score:89,Exploration Rate:0.06
# Game Episode :564/600, High Score:117,Exploration Rate:0.059
# Game Episode :565/600, High Score:189,Exploration Rate:0.059
# Game Episode :566/600, High Score:199,Exploration Rate:0.059
# Game Episode :567/600, High Score:199,Exploration Rate:0.059
# Game Episode :568/600, High Score:199,Exploration Rate:0.058
# Game Episode :569/600, High Score:199,Exploration Rate:0.058
# Game Episode :570/600, High Score:199,Exploration Rate:0.058
# Game Episode :571/600, High Score:199,Exploration Rate:0.057
# Game Episode :572/600, High Score:109,Exploration Rate:0.057
# Game Episode :573/600, High Score:96,Exploration Rate:0.057
# Game Episode :574/600, High Score:199,Exploration Rate:0.057
# Game Episode :575/600, High Score:199,Exploration Rate:0.056
# Game Episode :576/600, High Score:199,Exploration Rate:0.056
# Game Episode :577/600, High Score:199,Exploration Rate:0.056
# Game Episode :578/600, High Score:199,Exploration Rate:0.055
# Game Episode :579/600, High Score:199,Exploration Rate:0.055
# Game Episode :580/600, High Score:75,Exploration Rate:0.055
# Game Episode :581/600, High Score:176,Exploration Rate:0.055
# Game Episode :582/600, High Score:171,Exploration Rate:0.054
# Game Episode :583/600, High Score:199,Exploration Rate:0.054
# Game Episode :584/600, High Score:199,Exploration Rate:0.054
# Game Episode :585/600, High Score:199,Exploration Rate:0.054
# Game Episode :586/600, High Score:199,Exploration Rate:0.053
# Game Episode :587/600, High Score:199,Exploration Rate:0.053
# Game Episode :588/600, High Score:199,Exploration Rate:0.053
# Game Episode :589/600, High Score:199,Exploration Rate:0.052
# Game Episode :590/600, High Score:199,Exploration Rate:0.052
# Game Episode :591/600, High Score:199,Exploration Rate:0.052
# Game Episode :592/600, High Score:99,Exploration Rate:0.052
# Game Episode :593/600, High Score:83,Exploration Rate:0.051
# Game Episode :594/600, High Score:199,Exploration Rate:0.051
# Game Episode :595/600, High Score:199,Exploration Rate:0.051
# Game Episode :596/600, High Score:75,Exploration Rate:0.051
# Game Episode :597/600, High Score:199,Exploration Rate:0.05
# Game Episode :598/600, High Score:199,Exploration Rate:0.05
# Game Episode :599/600, High Score:199,Exploration Rate:0.05

# %%
`
